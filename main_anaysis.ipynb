# %% [markdown]
# <a href="https://colab.research.google.com/github/Pedro-Bonavita/scrum-practice-bootcamp/blob/main/main_anaysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Projeto: Simulação de Análise de Dados (SCRUM)
# **Bootcamp:** Data Science / Analytics Engineering
# **Sprint:** 01
# **Responsável:** Pedro
# **Descrição:** Este notebook contém a estrutura inicial para limpeza e análise exploratória de dados, seguindo a metodologia ágil.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Configurações de visualização
# %matplotlib inline
sns.set_theme(style="whitegrid")

print("Bibliotecas carregadas com sucesso!")
# Out:
# Bibliotecas carregadas com sucesso!

# %% [markdown]
# ## 1. Coleta de Dados (Data Collection)
# Nesta etapa, carregamos o dataset para o ambiente.
# *Nota: Substitua o link abaixo pela sua fonte de dados real.*

# %% [markdown]
# ## 2. Limpeza e Tratamento (Data Cleaning)
# [cite_start]Identificação de valores nulos, duplicatas e correção de tipos de dados. [cite: 4]
